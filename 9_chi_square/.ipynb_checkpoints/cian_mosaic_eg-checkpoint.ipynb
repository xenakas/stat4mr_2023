# %%
library("broom")
library("ggplot2")
library("vcd")
# library(janitor) 
library(dplyr)
# options(warn=0)
library(sandwich)
library(forecast)
# library(tsoutliers)
library(lmtest)

# %%
# install.packages('vcd')

# %%
df1 <- read.csv(file="cian_curdata.csv", header=TRUE, sep=",", stringsAsFactors = TRUE)

# %%
# df2  <-  df1  %>%  distinct(Rooms, Price, Totsp, flat_lat, flat_lon,  NFloor,  .keep_all= TRUE)  
# write.csv(df2, 'cian_curdata.csv')

# %%
# df1

# %%
df1['RoomspMean'] = df1['Livesp']/df1['Rooms']

# %%
df1['KitspShare'] = df1['Kitsp']/df1['Totsp']

# %%
df1['ClosestNeighbour'] = df1['X']
df1['ClosestNeighbourKm'] = 0
# df1['MetrdistFilled'] = df1['Metrdist']

# %%
dfp1 = df1[df1['DistrictName']=='', ]
dfp2 = df1[df1['DistrictName']!='', ]

# %%
dfp2[dfp2['X']==33721,]
# Out:
#      X.2  X.1  X     Rooms Price   Totsp Livesp Kitsp Dist     Metrdist ⋯
# 3601 4645 4645 33721 2     7800000 37    21.8   7     5.413835 15       ⋯
#      AllRoomsArea Url                                      LogPrice RoomspMean
# 3601 10,6+11,2    https://www.cian.ru/sale/flat/228412453/ 15.86963 10.9
#      KitspShare ClosestNeighbour ClosestNeighbourKm AgeDiff AvgFloor FloorDiff
# 3601 0.1891892  33721            0                  -4      15       -6

# %%
# for (i in 1:dim(dfp1)[1]){
#     dfp1[i, 'ClosestNeighbourKm'] = min((dfp2[['FlatLat']] - dfp1[i, 'FlatLat'])**2+(dfp2[['FlatLon']] - dfp1[i, 'FlatLon'])**2)*111
#     a = which.min((dfp2[['FlatLat']] - dfp1[i, 'FlatLat'])**2+(dfp2[['FlatLon']] - dfp1[i, 'FlatLon'])**2)
#     dfp1[i, 'ClosestNeighbour'] = dfp2[a,'X']
# }

# dfp3 = dfp1

# for (i in 1:dim(dfp1)[1]){
#       dfp3[i,'DistrictName'] = dfp2[dfp2['X']==dfp1[i, 'ClosestNeighbour'], 'DistrictName']
#       dfp3[i,'AvgAge'] = dfp2[dfp2['X']==dfp1[i, 'ClosestNeighbour'], 'AvgAge']
#       dfp3[i,'AvgSqmPr'] = dfp2[dfp2['X']==dfp1[i, 'ClosestNeighbour'], 'AvgSqmPr']
#       dfp3[i,'AvgRentPr'] = dfp2[dfp2['X']==dfp1[i, 'ClosestNeighbour'], 'AvgRentPr']  
# #       dfp3[i,'MetrdistFilled'] = dfp2[dfp2['X']==dfp1[i, 'ClosestNeighbour'], 'MetrdistFilled'] 
# #       dfp3[i,'Walk'] = dfp2[dfp2['X']==dfp1[i, 'ClosestNeighbour'], 'Walk'] 
# #     dfp1[i, 'ClosestNeighbourKm'] = min((dfp2[['FlatLat']] - dfp1[i, 'FlatLat'])**2+(dfp2[['FlatLon']] - dfp1[i, 'FlatLon'])**2)*111
# #     a = which.min((dfp2[['FlatLat']] - dfp1[i, 'FlatLat'])**2+(dfp2[['FlatLon']] - dfp1[i, 'FlatLon'])**2)
# #     dfp1[i, 'ClosestNeighbour'] = dfp2[a,'X']
# }

# %%
df2 = rbind(dfp2, dfp3)

# %%
distr = as.character(unique(df2[['DistrictName']]))

# %%
df2['AgeDiff'] = df2['HouseAge'] - df2['AvgAge']

# %%
df2['AvgFloor'] = 0

# %%
# for (i in 1:length(distr)){
#     dfch = df2[df2['DistrictName']== distr[i],'Floors']
#     df2[df2['DistrictName']== distr[i],'AvgFloor'] = mean(dfch)
# }

# %%
df2['AvgFloor'] = round(df2['AvgFloor'])

# %%
df2['FloorDiff'] = df2['Floors'] - df2['AvgFloor']

# %%
# write.csv(df2, 'cian_curdata.csv')

# %%
# colSums(is.na(df2))

# %%
# dfp3[is.na(dfp3['Metrdist']),]

# %%
# dfp1[dfp1['ClosestNeighbourKm']>0.01,]

# %%
# df1[df1['DistrictName']=='',30:58]

# %%
which.min((dfp2[['FlatLat']] - 55.779874)**2+(dfp2[['FlatLon']] - 37.573995)**2)
# Out:
# [1] 6872

# %%
df1=df2

# %%
mosaic( ~ Rooms +  AOName  , data = df1, shade = TRUE)
# Out:
# plot without title

# %%
mosaic( ~ Rooms +  AOName  + Walk , data = df1, shade = TRUE)
# Out:
# plot without title

# %%
mosaic( ~ Rooms +  AOName  + Brick , data = df1, shade = TRUE)
# Out:
# plot without title

# %%
# df2 = df1[!is.na(df1$house_material),]
df2 = df1[df1$HouseMaterial!='',]
mosaic( ~ Rooms   + HouseMaterial  +  AOName, data = df2, shade = TRUE)
# na.omit(df1, 'house_material')
# Out:
# plot without title

# %%
df3 = df1[df1$RemontType!='',]
mosaic( ~ Rooms   + RemontType  +  AOName, data = df3, shade = TRUE)
# Out:
# plot without title

# %%
df4 = df1[df1$Demolish!='',]
mosaic( ~ Rooms   + Demolish  +  AOName, data = df4, shade = TRUE)
# Out:
# plot without title

# %%
df5 = df1[df1$PegToCur!='',]
mosaic( ~ Rooms   + PegToCur  +  AOName, data = df5, shade = TRUE)
# Out:
# plot without title

# %%
colnames(df1)
# Out:
#  [1] "X.2"                "X.1"                "X"
#  [4] "Rooms"              "Price"              "Totsp"
#  [7] "Livesp"             "Kitsp"              "Dist"
# [10] "Metrdist"           "Walk"               "Brick"
# [13] "Tel"                "Bal"                "Floor"
# [16] "New"                "Floors"             "NFloor"
# [19] "floor1"             "floor2"             "N"
# [22] "NE"                 "E"                  "SE"
# [25] "S"                  "SW"                 "W"
# [28] "NW"                 "Centr"              "Zelen"
# [31] "PegToCur"           "FlatLat"            "FlatLon"
# [34] "MetroColor"         "MetroName"          "AOName"
# [37] "DistrictName"       "AvgAge"             "AvgSqmPr"
# [40] "AvgRentPr"          "Height"             "Demolish"
# [43] "HouseAge"           "HouseMaterial"      "BalNum"
# [46] "LoggiasNum"         "WCCombinedNum"      "WCSeparateNum"
# [49] "RemontType"         "WindowView"         "TotFlatNum"
# [52] "EntrancesNum"       "ParkingType"        "PasLiftNum"
# [55] "ImagesNum"          "SimilarNum"         "MortgageAllowed"
# [58] "AllRoomsArea"       "Url"                "LogPrice"
# [61] "RoomspMean"         "KitspShare"         "ClosestNeighbour"
# [64] "ClosestNeighbourKm" "AgeDiff"            "AvgFloor"
# [67] "FloorDiff"

# %%
df1['Totsp2']  = df1['Totsp']^2  
df1['Height2']  = df1['Height']^2  
df1['HouseAge2']  = df1['HouseAge']^2  
df1['NFloor2']  = df1['NFloor']^2  
df1['AgeDiff2']  = df1['AgeDiff']^2  
df1['RoomspMean2']  = df1['RoomspMean']^2

# %%
lm1 = lm(LogPrice~Rooms+Totsp+Totsp2+Dist+Metrdist+Walk+Brick+Floors+NFloor+NFloor2+
         floor1+floor2+ N + S+Height+Height2 + PegToCur+Demolish+ HouseAge+ HouseAge2+TotFlatNum+
         RoomspMean + RoomspMean2+ KitspShare + AgeDiff + AgeDiff2 , data = df1)
summary(lm1)
# Out:
# Call:
# lm(formula = LogPrice ~ Rooms + Totsp + Totsp2 + Dist + Metrdist +
#     Walk + Brick + Floors + NFloor + NFloor2 + floor1 + floor2 +
#     N + S + Height + Height2 + PegToCur + Demolish + HouseAge +
#     HouseAge2 + TotFlatNum + RoomspMean + RoomspMean2 + KitspShare +
#     AgeDiff + AgeDiff2, data = df1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.74929 -0.10935 -0.00875  0.09692  1.18162
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.616e+01  4.296e-01  37.622  < 2e-16 ***
# Rooms       -5.956e-02  1.685e-02  -3.535 0.000414 ***
# Totsp        2.571e-02  1.252e-03  20.534  < 2e-16 ***
# Totsp2      -6.128e-05  5.623e-06 -10.899  < 2e-16 ***
# Dist        -2.858e-02  1.480e-03 -19.306  < 2e-16 ***
# Metrdist    -4.786e-03  9.073e-04  -5.275 1.42e-07 ***
# Walk         7.470e-02  1.374e-02   5.437 5.83e-08 ***
# Brick        4.116e-02  1.135e-02   3.627 0.000292 ***
# Floors      -5.593e-04  9.691e-04  -0.577 0.563871
# NFloor       4.326e-03  1.680e-03   2.575 0.010078 *
# NFloor2     -1.134e-04  5.428e-05  -2.089 0.036777 *
# floor1      -9.270e-02  1.504e-02  -6.163 8.06e-10 ***
# floor2      -4.873e-02  1.392e-02  -3.502 0.000469 ***
# N           -2.363e-01  1.604e-02 -14.726  < 2e-16 ***
# S           -2.212e-01  1.710e-02 -12.937  < 2e-16 ***
# Height      -4.318e-01  2.850e-01  -1.515 0.129945
# Height2      1.158e-01  4.724e-02   2.451 0.014313 *
# PegToCur     4.395e-01  3.253e-02  13.511  < 2e-16 ***
# Demolish     7.225e-02  3.180e-02   2.272 0.023140 *
# HouseAge    -1.802e-03  8.406e-04  -2.144 0.032126 *
# HouseAge2    2.198e-07  5.883e-06   0.037 0.970199
# TotFlatNum  -3.911e-05  1.690e-05  -2.315 0.020690 *
# RoomspMean  -1.925e-02  4.910e-03  -3.921 9.02e-05 ***
# RoomspMean2  3.730e-04  9.421e-05   3.960 7.67e-05 ***
# KitspShare   3.480e-01  1.025e-01   3.397 0.000691 ***
# AgeDiff      7.954e-04  6.429e-04   1.237 0.216087
# AgeDiff2     5.256e-05  6.445e-06   8.156 4.99e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.201 on 3091 degrees of freedom
#   (5644 observations deleted due to missingness)
# Multiple R-squared:  0.9051,	Adjusted R-squared:  0.9043
# F-statistic:  1133 on 26 and 3091 DF,  p-value: < 2.2e-16

# %%
lm1 = lm(LogPrice~Rooms+Totsp+Totsp2+Dist+I(Metrdist*Brick)+Walk+Floors+NFloor+NFloor2+
         floor1+floor2+ N + S+Height+Height2 + PegToCur+Demolish+ HouseAge+ HouseAge2+TotFlatNum+
         RoomspMean + RoomspMean2+ KitspShare + AgeDiff + AgeDiff2 , data = df1)
summary(lm1)
# Out:
# Call:
# lm(formula = LogPrice ~ Rooms + Totsp + Totsp2 + Dist + I(Metrdist *
#     Brick) + Walk + Floors + NFloor + NFloor2 + floor1 + floor2 +
#     N + S + Height + Height2 + PegToCur + Demolish + HouseAge +
#     HouseAge2 + TotFlatNum + RoomspMean + RoomspMean2 + KitspShare +
#     AgeDiff + AgeDiff2, data = df1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.73760 -0.11304 -0.00875  0.10016  1.18267
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)          1.552e+01  4.242e-01  36.583  < 2e-16 ***
# Rooms               -6.490e-02  1.693e-02  -3.834 0.000129 ***
# Totsp                2.624e-02  1.257e-03  20.876  < 2e-16 ***
# Totsp2              -6.323e-05  5.649e-06 -11.193  < 2e-16 ***
# Dist                -2.975e-02  1.480e-03 -20.099  < 2e-16 ***
# I(Metrdist * Brick) -1.328e-03  9.295e-04  -1.429 0.153220
# Walk                 6.348e-02  1.364e-02   4.654 3.39e-06 ***
# Floors              -5.995e-04  9.748e-04  -0.615 0.538616
# NFloor               3.871e-03  1.689e-03   2.291 0.022008 *
# NFloor2             -9.320e-05  5.451e-05  -1.710 0.087413 .
# floor1              -9.478e-02  1.513e-02  -6.264 4.28e-10 ***
# floor2              -4.898e-02  1.400e-02  -3.497 0.000477 ***
# N                   -2.327e-01  1.613e-02 -14.429  < 2e-16 ***
# S                   -2.245e-01  1.719e-02 -13.060  < 2e-16 ***
# Height              -4.222e-02  2.819e-01  -0.150 0.880949
# Height2              5.769e-02  4.690e-02   1.230 0.218838
# PegToCur             4.391e-01  3.273e-02  13.413  < 2e-16 ***
# Demolish             9.142e-02  3.193e-02   2.863 0.004229 **
# HouseAge            -1.783e-03  8.451e-04  -2.109 0.034988 *
# HouseAge2            2.999e-06  5.905e-06   0.508 0.611560
# TotFlatNum          -3.423e-05  1.696e-05  -2.018 0.043706 *
# RoomspMean          -1.970e-02  4.940e-03  -3.988 6.82e-05 ***
# RoomspMean2          3.779e-04  9.478e-05   3.987 6.85e-05 ***
# KitspShare           3.439e-01  1.031e-01   3.336 0.000861 ***
# AgeDiff              4.571e-04  6.446e-04   0.709 0.478365
# AgeDiff2             4.952e-05  6.466e-06   7.658 2.51e-14 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2023 on 3092 degrees of freedom
#   (5644 observations deleted due to missingness)
# Multiple R-squared:  0.9038,	Adjusted R-squared:  0.9031
# F-statistic:  1163 on 25 and 3092 DF,  p-value: < 2.2e-16

# %%
lm1 = lm(LogPrice~Rooms+Totsp+Totsp2+Dist+Metrdist+NFloor+NFloor2+
         floor1+floor2+Height+Height2 + HouseAge+ HouseAge2+
         RoomspMean + RoomspMean2+ AgeDiff + AgeDiff2 + FloorDiff, data = df1)
summary(lm1)
# Out:
# Call:
# lm(formula = LogPrice ~ Rooms + Totsp + Totsp2 + Dist + Metrdist +
#     NFloor + NFloor2 + floor1 + floor2 + Height + Height2 + HouseAge +
#     HouseAge2 + RoomspMean + RoomspMean2 + AgeDiff + AgeDiff2 +
#     FloorDiff, data = df1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.85757 -0.12539 -0.01423  0.11243  1.48095
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.688e+01  3.823e-01  44.154  < 2e-16 ***
# Rooms       -7.040e-02  1.309e-02  -5.378 7.94e-08 ***
# Totsp        2.493e-02  1.066e-03  23.387  < 2e-16 ***
# Totsp2      -5.118e-05  4.863e-06 -10.525  < 2e-16 ***
# Dist        -3.110e-02  1.231e-03 -25.271  < 2e-16 ***
# Metrdist    -5.515e-03  8.145e-04  -6.771 1.45e-11 ***
# NFloor       5.516e-03  1.524e-03   3.619 0.000299 ***
# NFloor2     -6.190e-05  4.893e-05  -1.265 0.205984
# floor1      -8.888e-02  1.478e-02  -6.014 1.96e-09 ***
# floor2      -6.389e-02  1.358e-02  -4.705 2.62e-06 ***
# Height      -1.211e+00  2.545e-01  -4.757 2.03e-06 ***
# Height2      2.461e-01  4.232e-02   5.817 6.45e-09 ***
# HouseAge     6.069e-03  6.260e-04   9.695  < 2e-16 ***
# HouseAge2   -1.709e-05  4.997e-06  -3.420 0.000633 ***
# RoomspMean  -1.040e-02  4.415e-03  -2.357 0.018475 *
# RoomspMean2  3.206e-04  8.983e-05   3.570 0.000362 ***
# AgeDiff     -4.549e-03  5.139e-04  -8.851  < 2e-16 ***
# AgeDiff2     3.682e-05  5.512e-06   6.681 2.69e-11 ***
# FloorDiff   -2.610e-03  6.616e-04  -3.944 8.13e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2199 on 4180 degrees of freedom
#   (4563 observations deleted due to missingness)
# Multiple R-squared:  0.884,	Adjusted R-squared:  0.8835
# F-statistic:  1770 on 18 and 4180 DF,  p-value: < 2.2e-16

# %%
library(car)

# %%
linearHypothesis(lm1,c("NFloor2 = 0","Height2 = 0"),test="F")
# Out:
#   Res.Df RSS      Df Sum of Sq F        Pr(>F)
# 1 3094   126.7232 NA       NA        NA        NA
# 2 3092   126.5369  2 0.186297  2.276136 0.1028522

# %%
coeftest(lm1, vcov = vcovCL(lm1, cluster=df1$DistrictName, type="HC0"))
# Out:
# t test of coefficients:
#
#                        Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)          1.5520e+01  9.8424e-01 15.7686 < 2.2e-16 ***
# Rooms               -6.4904e-02  2.7798e-02 -2.3349 0.0196146 *
# Totsp                2.6237e-02  1.7496e-03 14.9960 < 2.2e-16 ***
# Totsp2              -6.3228e-05  1.0006e-05 -6.3188 3.014e-10 ***
# Dist                -2.9751e-02  5.6373e-03 -5.2774 1.400e-07 ***
# I(Metrdist * Brick) -1.3278e-03  1.3028e-03 -1.0192 0.3081817
# Walk                 6.3477e-02  2.1030e-02  3.0185 0.0025614 **
# Floors              -5.9947e-04  1.9140e-03 -0.3132 0.7541542
# NFloor               3.8709e-03  2.5749e-03  1.5033 0.1328580
# NFloor2             -9.3205e-05  1.0880e-04 -0.8566 0.3917166
# floor1              -9.4781e-02  1.5414e-02 -6.1492 8.787e-10 ***
# floor2              -4.8977e-02  1.5911e-02 -3.0782 0.0021010 **
# N                   -2.3271e-01  6.2935e-02 -3.6976 0.0002214 ***
# S                   -2.2450e-01  6.6016e-02 -3.4007 0.0006806 ***
# Height              -4.2221e-02  6.0052e-01 -0.0703 0.9439540
# Height2              5.7685e-02  1.0191e-01  0.5661 0.5713886
# PegToCur             4.3905e-01  1.0027e-01  4.3789 1.233e-05 ***
# Demolish             9.1417e-02  2.5961e-02  3.5213 0.0004357 ***
# HouseAge            -1.7827e-03  3.5616e-03 -0.5005 0.6167364
# HouseAge2            2.9991e-06  1.0860e-05  0.2762 0.7824445
# TotFlatNum          -3.4227e-05  4.0363e-05 -0.8480 0.3965114
# RoomspMean          -1.9701e-02  7.1245e-03 -2.7652 0.0057220 **
# RoomspMean2          3.7787e-04  1.8501e-04  2.0424 0.0411955 *
# KitspShare           3.4395e-01  1.0557e-01  3.2579 0.0011347 **
# AgeDiff              4.5706e-04  2.7040e-03  0.1690 0.8657798
# AgeDiff2             4.9520e-05  1.3652e-05  3.6272 0.0002912 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
df2 = df1[df1$AOName == 'САО',]
df2 = df2[order(df2$Dist), ]
lm2 = lm(LogPrice~Rooms+Totsp+Totsp2+Dist+Metrdist+Walk+Brick+Floors+NFloor+NFloor2+
         floor1+floor2+Height+Height2 +PegToCur+Demolish+ HouseAge+HouseAge2+ TotFlatNum+
         RoomspMean + RoomspMean2+ KitspShare + AgeDiff + AgeDiff2 + FloorDiff, data = df2)
# , weights = Dist
summary(lm2)
# Out:
# Call:
# lm(formula = LogPrice ~ Rooms + Totsp + Totsp2 + Dist + Metrdist +
#     Walk + Brick + Floors + NFloor + NFloor2 + floor1 + floor2 +
#     Height + Height2 + PegToCur + Demolish + HouseAge + HouseAge2 +
#     TotFlatNum + RoomspMean + RoomspMean2 + KitspShare + AgeDiff +
#     AgeDiff2 + FloorDiff, data = df2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.37201 -0.09570 -0.01366  0.08526  0.84012
#
# Coefficients: (1 not defined because of singularities)
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.473e+01  8.336e-01  17.672  < 2e-16 ***
# Rooms       -4.650e-02  2.312e-02  -2.011 0.044573 *
# Totsp        2.438e-02  1.875e-03  13.003  < 2e-16 ***
# Totsp2      -6.148e-05  9.123e-06  -6.739 2.80e-11 ***
# Dist        -3.462e-02  2.058e-03 -16.826  < 2e-16 ***
# Metrdist    -3.261e-03  1.166e-03  -2.796 0.005276 **
# Walk         7.166e-02  1.601e-02   4.477 8.51e-06 ***
# Brick        8.064e-02  1.315e-02   6.133 1.28e-09 ***
# Floors       2.583e-03  1.155e-03   2.236 0.025574 *
# NFloor       6.878e-03  2.442e-03   2.817 0.004958 **
# NFloor2     -2.363e-04  8.323e-05  -2.839 0.004623 **
# floor1      -7.792e-02  2.001e-02  -3.895 0.000105 ***
# floor2      -1.246e-02  1.861e-02  -0.670 0.503341
# Height       6.265e-01  5.810e-01   1.078 0.281185
# Height2     -8.460e-02  1.001e-01  -0.845 0.398239
# PegToCur     1.447e-01  8.506e-02   1.702 0.089152 .
# Demolish     9.584e-02  3.347e-02   2.863 0.004288 **
# HouseAge    -1.188e-03  1.431e-03  -0.830 0.406580
# HouseAge2   -2.252e-05  1.653e-05  -1.363 0.173322
# TotFlatNum  -3.407e-05  1.903e-05  -1.790 0.073700 .
# RoomspMean  -3.040e-02  8.762e-03  -3.469 0.000546 ***
# RoomspMean2  5.857e-04  1.976e-04   2.964 0.003114 **
# KitspShare   3.287e-01  1.326e-01   2.479 0.013353 *
# AgeDiff      7.050e-04  9.571e-04   0.737 0.461567
# AgeDiff2     2.175e-05  1.603e-05   1.357 0.175155
# FloorDiff           NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1449 on 928 degrees of freedom
#   (1752 observations deleted due to missingness)
# Multiple R-squared:  0.8978,	Adjusted R-squared:  0.8952
# F-statistic: 339.8 on 24 and 928 DF,  p-value: < 2.2e-16

# %%
coeftest(lm2, vcov = vcovCL(lm2, cluster=df2$DistrictName, type="HC1"))
# Out:
# t test of coefficients:
#
#                Estimate  Std. Error  t value  Pr(>|t|)
# (Intercept)  1.4732e+01  1.1555e+00  12.7491 < 2.2e-16 ***
# Rooms       -4.6504e-02  1.2573e-02  -3.6988 0.0002293 ***
# Totsp        2.4384e-02  1.2803e-03  19.0458 < 2.2e-16 ***
# Totsp2      -6.1478e-05  5.1364e-06 -11.9689 < 2.2e-16 ***
# Dist        -3.4620e-02  5.3652e-03  -6.4527 1.767e-10 ***
# Metrdist    -3.2606e-03  1.7077e-03  -1.9094 0.0565179 .
# Walk         7.1663e-02  2.5519e-02   2.8082 0.0050861 **
# Brick        8.0643e-02  1.6255e-02   4.9610 8.340e-07 ***
# Floors       2.5834e-03  2.2430e-03   1.1518 0.2497069
# NFloor       6.8781e-03  2.4010e-03   2.8647 0.0042681 **
# NFloor2     -2.3629e-04  8.7953e-05  -2.6866 0.0073481 **
# floor1      -7.7921e-02  1.6835e-02  -4.6284 4.209e-06 ***
# floor2      -1.2459e-02  2.4279e-02  -0.5132 0.6079602
# Height       6.2649e-01  7.9084e-01   0.7922 0.4284618
# Height2     -8.4597e-02  1.3256e-01  -0.6382 0.5235280
# PegToCur     1.4474e-01  1.3295e-01   1.0887 0.2765615
# Demolish     9.5841e-02  3.3569e-02   2.8551 0.0043989 **
# HouseAge    -1.1879e-03  2.4208e-03  -0.4907 0.6237450
# HouseAge2   -2.2521e-05  2.8730e-05  -0.7839 0.4333058
# TotFlatNum  -3.4067e-05  2.3087e-05  -1.4755 0.1404067
# RoomspMean  -3.0396e-02  1.0040e-02  -3.0273 0.0025354 **
# RoomspMean2  5.8573e-04  2.8022e-04   2.0902 0.0368690 *
# KitspShare   3.2867e-01  1.1717e-01   2.8051 0.0051346 **
# AgeDiff      7.0496e-04  2.9302e-03   0.2406 0.8099344
# AgeDiff2     2.1753e-05  2.7842e-05   0.7813 0.4348225
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
df3 = df1[df1$AOName == 'ЮАО',]
df3 = df3[order(df3$Dist), ]
lm3 = lm(LogPrice~Rooms+Totsp+Totsp2+Dist+Metrdist+Walk+Brick+Floors+NFloor+NFloor2+
         floor1+floor2+Height+Height2+ PegToCur+Demolish+ HouseAge+ HouseAge2+TotFlatNum+
         RoomspMean+RoomspMean2 + KitspShare + AgeDiff  + AgeDiff2+ FloorDiff, data = df3)
summary(lm3)
# Out:
# Call:
# lm(formula = LogPrice ~ Rooms + Totsp + Totsp2 + Dist + Metrdist +
#     Walk + Brick + Floors + NFloor + NFloor2 + floor1 + floor2 +
#     Height + Height2 + PegToCur + Demolish + HouseAge + HouseAge2 +
#     TotFlatNum + RoomspMean + RoomspMean2 + KitspShare + AgeDiff +
#     AgeDiff2 + FloorDiff, data = df3)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.33562 -0.07392 -0.00875  0.06461  0.60401
#
# Coefficients: (1 not defined because of singularities)
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.720e+01  7.102e-01  24.224  < 2e-16 ***
# Rooms       -8.512e-03  1.956e-02  -0.435 0.663569
# Totsp        2.388e-02  1.546e-03  15.449  < 2e-16 ***
# Totsp2      -6.940e-05  7.367e-06  -9.420  < 2e-16 ***
# Dist        -2.585e-02  1.384e-03 -18.674  < 2e-16 ***
# Metrdist    -5.155e-03  8.095e-04  -6.368 2.76e-10 ***
# Walk         1.061e-01  1.174e-02   9.039  < 2e-16 ***
# Brick        1.366e-02  1.152e-02   1.186 0.235693
# Floors       2.026e-04  1.124e-03   0.180 0.856937
# NFloor       7.362e-03  1.927e-03   3.820 0.000141 ***
# NFloor2     -2.230e-04  7.878e-05  -2.831 0.004727 **
# floor1      -5.591e-02  1.401e-02  -3.991 7.01e-05 ***
# floor2      -3.176e-02  1.394e-02  -2.278 0.022886 *
# Height      -1.512e+00  4.888e-01  -3.093 0.002027 **
# Height2      2.968e-01  8.665e-02   3.426 0.000635 ***
# PegToCur     1.736e-01  1.184e-01   1.465 0.143063
# Demolish     4.925e-02  2.887e-02   1.706 0.088301 .
# HouseAge     1.405e-03  1.328e-03   1.057 0.290517
# HouseAge2   -2.502e-05  1.313e-05  -1.905 0.057041 .
# TotFlatNum  -1.305e-05  1.769e-05  -0.738 0.460882
# RoomspMean  -1.252e-03  8.714e-03  -0.144 0.885819
# RoomspMean2 -1.348e-04  2.136e-04  -0.631 0.528091
# KitspShare   4.373e-01  1.120e-01   3.904 0.000100 ***
# AgeDiff     -7.165e-04  8.160e-04  -0.878 0.380060
# AgeDiff2     8.716e-05  1.383e-05   6.304 4.13e-10 ***
# FloorDiff           NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1153 on 1148 degrees of freedom
#   (1736 observations deleted due to missingness)
# Multiple R-squared:  0.9253,	Adjusted R-squared:  0.9237
# F-statistic: 592.2 on 24 and 1148 DF,  p-value: < 2.2e-16

# %%
# coeftest(lm3, vcov = vcovCL(lm3, cluster=df3$DistrictName, type="HC1"))

# %%
df4 = df1[df1$AOName == 'ЦАО',]
df4 = df4[order(df4$Dist), ]
lm4 = lm(LogPrice~Rooms+Totsp+Totsp2+Dist+Metrdist+Walk+Brick+Floors+NFloor+NFloor2+
         floor1+floor2+ Height+ Height2+PegToCur+Demolish+ HouseAge + HouseAge2+ TotFlatNum+
         RoomspMean+RoomspMean2 + KitspShare + AgeDiff + AgeDiff2+ FloorDiff, data = df4)
summary(lm4)
# Out:
# Call:
# lm(formula = LogPrice ~ Rooms + Totsp + Totsp2 + Dist + Metrdist +
#     Walk + Brick + Floors + NFloor + NFloor2 + floor1 + floor2 +
#     Height + Height2 + PegToCur + Demolish + HouseAge + HouseAge2 +
#     TotFlatNum + RoomspMean + RoomspMean2 + KitspShare + AgeDiff +
#     AgeDiff2 + FloorDiff, data = df4)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.72935 -0.17123 -0.02187  0.15083  1.03203
#
# Coefficients: (1 not defined because of singularities)
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.339e+01  8.419e-01  15.903  < 2e-16 ***
# Rooms       -5.816e-02  3.330e-02  -1.747 0.080998 .
# Totsp        2.616e-02  2.380e-03  10.994  < 2e-16 ***
# Totsp2      -6.142e-05  1.022e-05  -6.011 2.61e-09 ***
# Dist        -1.478e-01  8.834e-03 -16.729  < 2e-16 ***
# Metrdist     1.892e-03  2.495e-03   0.758 0.448475
# Walk        -1.238e-01  7.664e-02  -1.616 0.106491
# Brick        1.049e-01  3.126e-02   3.354 0.000827 ***
# Floors       1.862e-03  2.351e-03   0.792 0.428659
# NFloor       3.044e-03  3.938e-03   0.773 0.439655
# NFloor2     -2.673e-05  9.693e-05  -0.276 0.782799
# floor1      -1.507e-01  3.598e-02  -4.187 3.08e-05 ***
# floor2      -5.808e-02  2.961e-02  -1.961 0.050136 .
# Height       1.553e+00  5.483e-01   2.832 0.004728 **
# Height2     -2.084e-01  8.747e-02  -2.382 0.017395 *
# PegToCur     4.007e-01  4.467e-02   8.972  < 2e-16 ***
# Demolish     1.835e-01  1.323e-01   1.387 0.165753
# HouseAge    -1.640e-04  2.234e-03  -0.073 0.941505
# HouseAge2   -4.620e-07  1.735e-05  -0.027 0.978769
# TotFlatNum  -1.219e-04  4.945e-05  -2.465 0.013876 *
# RoomspMean  -1.307e-02  9.199e-03  -1.421 0.155581
# RoomspMean2  1.927e-04  1.599e-04   1.205 0.228397
# KitspShare   3.633e-01  2.161e-01   1.681 0.093074 .
# AgeDiff     -2.290e-03  1.323e-03  -1.731 0.083772 .
# AgeDiff2     3.836e-05  1.720e-05   2.231 0.025937 *
# FloorDiff           NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2575 on 967 degrees of freedom
#   (2158 observations deleted due to missingness)
# Multiple R-squared:  0.8455,	Adjusted R-squared:  0.8416
# F-statistic: 220.4 on 24 and 967 DF,  p-value: < 2.2e-16

# %%
# c4 =
# coeftest(lm4, vcov = vcovCL(lm4, cluster=df4$DistrictName, type="HC1"))

# %%
bptest(lm1)
bptest(lm2)
bptest(lm3)
bptest(lm4)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  lm1
# BP = 580.01, df = 26, p-value < 2.2e-16
# 	studentized Breusch-Pagan test
#
# data:  lm2
# BP = 69.033, df = 24, p-value = 3.061e-06
# 	studentized Breusch-Pagan test
#
# data:  lm3
# BP = 186.97, df = 24, p-value < 2.2e-16
# 	studentized Breusch-Pagan test
#
# data:  lm4
# BP = 124.26, df = 24, p-value = 1.679e-15

# %%
checkresiduals(lm1)
checkresiduals(lm2)
checkresiduals(lm3)
checkresiduals(lm4)
# Out:
# 	Breusch-Godfrey test for serial correlation of order up to 31
#
# data:  Residuals
# LM test = 76.718, df = 31, p-value = 9.521e-06
# plot without title
# 	Breusch-Godfrey test for serial correlation of order up to 29
#
# data:  Residuals
# LM test = 89.649, df = 29, p-value = 4.122e-08
# plot without title
# 	Breusch-Godfrey test for serial correlation of order up to 29
#
# data:  Residuals
# LM test = 84.511, df = 29, p-value = 2.485e-07
# plot without title
# 	Breusch-Godfrey test for serial correlation of order up to 29
#
# data:  Residuals
# LM test = 123.15, df = 29, p-value = 1.433e-13
# plot without title

# %%
ggtsdisplay(lm2$residuals)
ggtsdisplay(lm3$residuals)
ggtsdisplay(lm4$residuals)
# Out:
# plot without title
# plot without title
# plot without title

# %%
bgtest(lm1, order = 1, order.by = ~Dist, data=data.frame(lm1[[7]][[1]]))
bgtest(lm2, order = 1, order.by = ~Dist, data=data.frame(lm2[[7]][[1]]))
bgtest(lm3, order = 1, order.by = ~Dist, data=data.frame(lm3[[7]][[1]]))
bgtest(lm4, order = 1, order.by = ~Dist, data=data.frame(lm4[[7]][[1]]))
# Out:
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  lm1
# LM test = 13.575, df = 1, p-value = 0.0002292
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  lm2
# LM test = 13.64, df = 1, p-value = 0.0002215
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  lm3
# LM test = 0.74938, df = 1, p-value = 0.3867
# 	Breusch-Godfrey test for serial correlation of order up to 1
#
# data:  lm4
# LM test = 21.375, df = 1, p-value = 3.777e-06

# %%
resettest(lm1) 
resettest(lm2) 
resettest(lm3) 
resettest(lm4) 
# , vcov = vcovCL(lm4, cluster=df4$DistrictName, type="HC1"))
# Out:
# 	RESET test
#
# data:  lm1
# RESET = 111.82, df1 = 2, df2 = 3088, p-value < 2.2e-16
# 	RESET test
#
# data:  lm2
# RESET = 3.4604, df1 = 2, df2 = 925, p-value = 0.03183
# 	RESET test
#
# data:  lm3
# RESET = 25.959, df1 = 2, df2 = 1145, p-value = 9.424e-12
# 	RESET test
#
# data:  lm4
# RESET = 7.2934, df1 = 2, df2 = 964, p-value = 0.0007182

# %%
shapiro.test(lm1$residuals)
shapiro.test(lm2$residuals)
shapiro.test(lm3$residuals)
shapiro.test(lm4$residuals)
shapiro.test(rnorm(100, mean = 5, sd = 3))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  lm1$residuals
# W = 0.96181, p-value < 2.2e-16
# 	Shapiro-Wilk normality test
#
# data:  lm2$residuals
# W = 0.97876, p-value = 1.441e-10
# 	Shapiro-Wilk normality test
#
# data:  lm3$residuals
# W = 0.98153, p-value = 4.54e-11
# 	Shapiro-Wilk normality test
#
# data:  lm4$residuals
# W = 0.98369, p-value = 4.39e-09
# 	Shapiro-Wilk normality test
#
# data:  rnorm(100, mean = 5, sd = 3)
# W = 0.98431, p-value = 0.2827

# %%
test <- vector('list', 50)
test[[1]] <- list(coef0 = coef(lm2), res0 = lm2$residuals)

wls_func_lm <- function(obj){
  weight <- obj[['res0']]^2
  lm_reg <- lm(LogPrice~Rooms+Totsp+Totsp2+Dist+Metrdist+Walk+Brick+Floors+NFloor+NFloor2+
         floor1+floor2+ Height+ Height2+PegToCur+Demolish+ HouseAge + HouseAge2+ TotFlatNum+
         RoomspMean+RoomspMean2 + KitspShare + AgeDiff + AgeDiff2+ FloorDiff, 
               data = data.frame(lm2[[7]][[1]]), weights = 1/weight)
  lm_reg_res <- lm(lm_reg$residuals^2 ~ Rooms+Totsp+Totsp2+Dist+Metrdist+Walk+Brick+Floors+NFloor+NFloor2+
         floor1+floor2+ Height+ Height2+PegToCur+Demolish+ HouseAge + HouseAge2+ TotFlatNum+
         RoomspMean+RoomspMean2 + KitspShare + AgeDiff + AgeDiff2+ FloorDiff,
                   data = data.frame(lm2[[7]][[1]]))
  return(list(coef0 = coef(lm_reg), res0 = lm_reg_res$fitted.values)) 
}
for (i in 1:10){
test[[i+1]] <- wls_func_lm(test[[i]])
dif <- sum(test[[i+1]][['coef0']] - test[[i]][['coef0']])^2
cat(i, test[[i]][['coef0']], dif , '\n')
}
# Out:
# Error in eval(predvars, data, env): object 'LogPrice' not found
# Traceback:
#
# 1. wls_func_lm(test[[i]])
# 2. lm(LogPrice ~ Rooms + Totsp + Totsp2 + Dist + Metrdist + Walk +
#  .     Brick + Floors + NFloor + NFloor2 + floor1 + floor2 + Height +
#  .     Height2 + PegToCur + Demolish + HouseAge + HouseAge2 + TotFlatNum +
#  .     RoomspMean + RoomspMean2 + KitspShare + AgeDiff + AgeDiff2 +
#  .     FloorDiff, data = data.frame(lm2[[7]][[1]]), weights = 1/weight)   # at line 6-9 of file <text>
# 3. eval(mf, parent.frame())
# 4. eval(mf, parent.frame())
# 5. stats::model.frame(formula = LogPrice ~ Rooms + Totsp + Totsp2 +
#  .     Dist + Metrdist + Walk + Brick + Floors + NFloor + NFloor2 +
#  .     floor1 + floor2 + Height + Height2 + PegToCur + Demolish +
#  .     HouseAge + HouseAge2 + TotFlatNum + RoomspMean + RoomspMean2 +
#  .     KitspShare + AgeDiff + AgeDiff2 + FloorDiff, data = data.frame(lm2[[7]][[1]]),
#  .     weights = 1/weight, drop.unused.levels = TRUE)
# 6. model.frame.default(formula = LogPrice ~ Rooms + Totsp + Totsp2 +
#  .     Dist + Metrdist + Walk + Brick + Floors + NFloor + NFloor2 +
#  .     floor1 + floor2 + Height + Height2 + PegToCur + Demolish +
#  .     HouseAge + HouseAge2 + TotFlatNum + RoomspMean + RoomspMean2 +
#  .     KitspShare + AgeDiff + AgeDiff2 + FloorDiff, data = data.frame(lm2[[7]][[1]]),
#  .     weights = 1/weight, drop.unused.levels = TRUE)
# 7. eval(predvars, data, env)
# 8. eval(predvars, data, env)

# %%
plot(lm2$residuals^2, cex = 0.7)
plot(lm3$residuals^2, cex = 0.7)
plot(lm4$residuals^2, cex = 0.7)
# Out:
# plot without title
# plot without title
# plot without title

# %%
# df2

# %%
# res_reg2 <- lm(lm2$residuals ~ lag(lm2$residuals)  +  lead(lm2$residuals,1) +    Rooms+Totsp+Totsp2+Dist+Metrdist+Walk+Brick+Floors+NFloor+NFloor2+
#          floor1+floor2+ Height+ Height2+PegToCur+Demolish+ HouseAge + HouseAge2+ TotFlatNum+
#          RoomspMean+RoomspMean2 + KitspShare + AgeDiff + AgeDiff2+ FloorDiff, data = data.frame(lm2[[7]][[1]]))
# res_reg3 <- lm(lm3$residuals ~ lag(lm3$residuals)  +  lead(lm3$residuals,1) +    Rooms+Totsp+Totsp2+Dist+Metrdist+Walk+Brick+Floors+NFloor+NFloor2+
#          floor1+floor2+ Height+ Height2+PegToCur+Demolish+ HouseAge + HouseAge2+ TotFlatNum+
#          RoomspMean+RoomspMean2 + KitspShare + AgeDiff + AgeDiff2+ FloorDiff, data = data.frame(lm3[[7]][[1]]))
# res_reg4 <- lm(lm4$residuals ~ lag(lm4$residuals)  +  lead(lm4$residuals,1) +    Rooms+Totsp+Totsp2+Dist+Metrdist+Walk+Brick+Floors+NFloor+NFloor2+
#          floor1+floor2+ Height+ Height2+PegToCur+Demolish+ HouseAge + HouseAge2+ TotFlatNum+
#          RoomspMean+RoomspMean2 + KitspShare + AgeDiff + AgeDiff2+ FloorDiff, data = data.frame(lm4[[7]][[1]]))

# %%
library(Hmisc)

# %%
latex(c2, digits=5)

# %%
latex(c3, digits=5)

# %%
latex(c4, digits=5)

# %%
c2 = coeftest(lm2, vcov = vcovCL(lm2, cluster=df2$DistrictName, type="HC1"))
c3 = coeftest(lm3, vcov = vcovCL(lm3, cluster=df3$DistrictName, type="HC1"))
c4 = coeftest(lm4, vcov = vcovCL(lm4, cluster=df4$DistrictName, type="HC1"))

# %%
c2
c3
c4
# Out:
# t test of coefficients:
#
#                Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)  1.4625e+01  1.1343e+00 12.8926 < 2.2e-16 ***
# Rooms       -4.5696e-02  1.0796e-02 -4.2328 2.538e-05 ***
# Totsp        2.3960e-02  1.4291e-03 16.7657 < 2.2e-16 ***
# Totsp2      -5.9342e-05  6.3456e-06 -9.3516 < 2.2e-16 ***
# Dist        -3.1298e-02  4.8669e-03 -6.4308 2.030e-10 ***
# Metrdist    -2.4017e-03  1.4832e-03 -1.6193  0.105724
# Walk         7.6425e-02  2.5552e-02  2.9910  0.002855 **
# Brick        7.7681e-02  1.6486e-02  4.7120 2.829e-06 ***
# Floors       1.2816e-02  3.7586e-03  3.4098  0.000678 ***
# NFloor       7.1118e-03  2.4786e-03  2.8692  0.004208 **
# NFloor2     -2.4653e-04  8.8146e-05 -2.7968  0.005268 **
# floor1      -7.8676e-02  1.7912e-02 -4.3924 1.251e-05 ***
# floor2      -1.2492e-02  2.3483e-02 -0.5319  0.594898
# Height       4.7468e-01  7.8372e-01  0.6057  0.544882
# Height2     -5.9400e-02  1.3130e-01 -0.4524  0.651086
# PegToCur     1.7084e-01  1.2627e-01  1.3530  0.176388
# Demolish     8.7643e-02  3.4467e-02  2.5429  0.011157 *
# HouseAge     1.4916e-03  2.8214e-03  0.5287  0.597154
# HouseAge2   -1.2137e-05  2.5236e-05 -0.4809  0.630685
# TotFlatNum  -4.8523e-05  2.6650e-05 -1.8207  0.068971 .
# RoomspMean  -3.2035e-02  1.0259e-02 -3.1226  0.001848 **
# RoomspMean2  6.0525e-04  2.8107e-04  2.1534  0.031546 *
# KitspShare   3.1321e-01  1.1359e-01  2.7573  0.005942 **
# AgeDiff     -2.8609e-03  3.6946e-03 -0.7743  0.438936
# AgeDiff2     1.0523e-05  2.4256e-05  0.4338  0.664524
# FloorDiff   -1.0266e-02  3.5465e-03 -2.8947  0.003885 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# t test of coefficients:
#
#                Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)  1.7196e+01  8.4824e-01 20.2723 < 2.2e-16 ***
# Rooms       -7.9323e-03  2.6719e-02 -0.2969 0.7666121
# Totsp        2.3894e-02  1.7636e-03 13.5483 < 2.2e-16 ***
# Totsp2      -6.9527e-05  8.1371e-06 -8.5445 < 2.2e-16 ***
# Dist        -2.5761e-02  3.5265e-03 -7.3050 5.179e-13 ***
# Metrdist    -5.1563e-03  1.0108e-03 -5.1013 3.945e-07 ***
# Walk         1.0631e-01  2.1682e-02  4.9030 1.080e-06 ***
# Brick        1.3223e-02  1.7745e-02  0.7452 0.4563328
# Floors       1.6132e-03  6.5927e-03  0.2447 0.8067380
# NFloor       7.3583e-03  1.9897e-03  3.6983 0.0002273 ***
# NFloor2     -2.2356e-04  7.7541e-05 -2.8831 0.0040115 **
# floor1      -5.5791e-02  1.2910e-02 -4.3217 1.683e-05 ***
# floor2      -3.1789e-02  1.2443e-02 -2.5548 0.0107533 *
# Height      -1.5312e+00  6.4276e-01 -2.3822 0.0173739 *
# Height2      3.0030e-01  1.1402e-01  2.6336 0.0085610 **
# PegToCur     1.7273e-01  7.1476e-02  2.4166 0.0158204 *
# Demolish     5.0002e-02  3.0287e-02  1.6510 0.0990206 .
# HouseAge     1.6071e-03  2.9738e-03  0.5404 0.5890126
# HouseAge2   -2.5037e-05  2.9909e-05 -0.8371 0.4027053
# TotFlatNum  -1.5210e-05  1.4662e-05 -1.0374 0.2997785
# RoomspMean  -1.4786e-03  1.3623e-02 -0.1085 0.9135874
# RoomspMean2 -1.2826e-04  3.1195e-04 -0.4112 0.6810266
# KitspShare   4.4674e-01  1.6121e-01  2.7712 0.0056755 **
# AgeDiff     -9.6666e-04  2.3564e-03 -0.4102 0.6817209
# AgeDiff2     8.6364e-05  1.9184e-05  4.5019 7.421e-06 ***
# FloorDiff   -1.5282e-03  5.6004e-03 -0.2729 0.7849974
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# t test of coefficients:
#
#                Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)  1.3394e+01  1.0618e+00 12.6147 < 2.2e-16 ***
# Rooms       -5.8433e-02  5.9759e-02 -0.9778 0.3284144
# Totsp        2.6162e-02  2.7198e-03  9.6192 < 2.2e-16 ***
# Totsp2      -6.1318e-05  9.8146e-06 -6.2477 6.237e-10 ***
# Dist        -1.4793e-01  3.4454e-02 -4.2935 1.936e-05 ***
# Metrdist     1.7825e-03  3.3385e-03  0.5339 0.5935269
# Walk        -1.2239e-01  8.9529e-02 -1.3671 0.1719243
# Brick        1.0388e-01  1.9083e-02  5.4435 6.625e-08 ***
# Floors       2.2881e-03  6.5991e-03  0.3467 0.7288673
# NFloor       3.0939e-03  3.1518e-03  0.9816 0.3265287
# NFloor2     -2.7175e-05  1.0257e-04 -0.2649 0.7911100
# floor1      -1.5052e-01  2.2067e-02 -6.8212 1.590e-11 ***
# floor2      -5.8788e-02  2.0663e-02 -2.8451 0.0045339 **
# Height       1.5396e+00  6.0239e-01  2.5557 0.0107491 *
# Height2     -2.0632e-01  9.6165e-02 -2.1454 0.0321665 *
# PegToCur     4.0121e-01  1.1226e-01  3.5738 0.0003692 ***
# Demolish     1.8147e-01  8.9458e-02  2.0286 0.0427761 *
# HouseAge    -3.2989e-05  6.2247e-03 -0.0053 0.9957726
# HouseAge2   -4.7273e-07  2.6570e-05 -0.0178 0.9858084
# TotFlatNum  -1.2023e-04  1.4258e-04 -0.8432 0.3993015
# RoomspMean  -1.3091e-02  1.0310e-02 -1.2698 0.2044553
# RoomspMean2  1.9278e-04  1.2228e-04  1.5765 0.1152320
# KitspShare   3.6144e-01  2.2929e-01  1.5764 0.1152722
# AgeDiff     -2.4364e-03  2.7723e-03 -0.8788 0.3797133
# AgeDiff2     3.8075e-05  1.5657e-05  2.4319 0.0152001 *
# FloorDiff   -6.0323e-04  3.7766e-03 -0.1597 0.8731277
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
JarqueBera.test(lm1$residuals)
JarqueBera.test(lm2$residuals)
JarqueBera.test(lm3$residuals)
JarqueBera.test(lm4$residuals)
# Out:
# 	Jarque Bera Test
#
# data:  lm1$residuals
# X-squared = 1169.7, df = 2, p-value < 2.2e-16
#
#
# 	Skewness
#
# data:  lm1$residuals
# statistic = 0.64054, p-value < 2.2e-16
#
#
# 	Kurtosis
#
# data:  lm1$residuals
# statistic = 5.7134, p-value < 2.2e-16
# 	Jarque Bera Test
#
# data:  lm2$residuals
# X-squared = 160.92, df = 2, p-value < 2.2e-16
#
#
# 	Skewness
#
# data:  lm2$residuals
# statistic = 0.63835, p-value = 8.622e-16
#
#
# 	Kurtosis
#
# data:  lm2$residuals
# statistic = 4.5564, p-value < 2.2e-16
# 	Jarque Bera Test
#
# data:  lm3$residuals
# X-squared = 163.84, df = 2, p-value < 2.2e-16
#
#
# 	Skewness
#
# data:  lm3$residuals
# statistic = 0.55429, p-value = 9.176e-15
#
#
# 	Kurtosis
#
# data:  lm3$residuals
# statistic = 4.4571, p-value < 2.2e-16
# 	Jarque Bera Test
#
# data:  lm4$residuals
# X-squared = 75.626, df = 2, p-value < 2.2e-16
#
#
# 	Skewness
#
# data:  lm4$residuals
# statistic = 0.50568, p-value = 7.92e-11
#
#
# 	Kurtosis
#
# data:  lm4$residuals
# statistic = 3.8982, p-value = 7.704e-09
