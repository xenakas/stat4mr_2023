# %%
df = read.csv('df_matching.csv') 
df_green = df[df['green'] == 1,]
df_not_green = df[df['green'] != 1,]

# %%
dim(df_green)
# Out:
# [1] 117  31

# %%
dim(df_not_green)
# Out:
# [1] 2230   31

# %%
# df

# %%
dim(df_green)
dim(df_not_green)
# Out:
# [1] 117  31
# [1] 2230   31

# %% [markdown]
# ### Mod 2

# %%
# MATCHING:
# Issue size
# Credit Rating
# Maturity
# Coupons

# %%
df_matching = df

# %%
library(MatchIt)

# %%
mat <- matchit(green ~ Amt_Issued + mty_years_frm + 
               years_to_maturity + YAS_Yield_Spread +
               X260D_volatility +  Cpn + 
               comp_return + roe + roe_bit  + 
               roc + number_of_former_directors + 
               number_of_executors, data = df_matching,
                 method = "nearest", distance = "glm")
summary(mat, un = FALSE)
# Out:
# Call:
# matchit(formula = green ~ Amt_Issued + mty_years_frm + years_to_maturity +
#     YAS_Yield_Spread + X260D_volatility + Cpn + comp_return +
#     roe + roe_bit + roc + number_of_former_directors + number_of_executors,
#     data = df_matching, method = "nearest", distance = "glm")
#
# Summary of Balance for Matched Data:
#                            Means Treated Means Control Std. Mean Diff.
# distance                          0.2197        0.1801          0.1849
# Amt_Issued                       39.7210       52.3728         -0.0827
# mty_years_frm                     7.6859        8.2236         -0.1227
# years_to_maturity                10.3571       10.9495         -0.1362
# YAS_Yield_Spread                154.3683      102.1860          1.2974
# X260D_volatility                  5.1010        5.2873         -0.0409
# Cpn                               5.2702        5.6264         -0.3923
# comp_return                   44020.9267    43946.4112          0.0010
# roe                             -34.9585        8.0155         -0.3147
# roe_bit                         -28.3480       14.0088         -0.3336
# roc                               0.0529       -0.4871          1.4991
# number_of_former_directors        5.5983        6.1384         -0.1889
# number_of_executors               5.1282        5.4960         -0.2275
#                            Var. Ratio eCDF Mean eCDF Max Std. Pair Dist.
# distance                       3.2637    0.0015   0.1282          0.1864
# Amt_Issued                     2.1807    0.1759   0.5385          0.4100
# mty_years_frm                  0.1951    0.1040   0.2137          1.7392
# years_to_maturity              0.1852    0.0959   0.2222          1.8081
# YAS_Yield_Spread               0.0881    0.2763   0.5214          2.5648
# X260D_volatility               0.3652    0.1216   0.2479          1.3729
# Cpn                            0.0641    0.1068   0.1966          2.4247
# comp_return                    0.6400    0.0405   0.3675          1.0255
# roe                            2.6250    0.1355   0.3504          0.6552
# roe_bit                        1.8968    0.1322   0.3504          0.7101
# roc                            0.0009    0.0750   0.8034          8.2597
# number_of_former_directors     0.2162    0.0461   0.2479          1.5749
# number_of_executors            0.0837    0.0708   0.3077          2.4058
#
# Sample Sizes:
#           Control Treated
# All          2230     117
# Matched       117     117
# Unmatched    2113       0
# Discarded       0       0

# %%
plot(mat, type = "jitter", interactive = FALSE)
# Out:
# Plot with title “Distribution of Propensity Scores”

# %%
plot(summary(mat))
# Out:
# plot without title

# %%
mch <- match.data(mat)

# %%
df_diff = data.frame(matrix(NA, nrow=0,ncol=30))
for (i in 1:177){
    df_1 = mch[mch['subclass']==i,]
    df_diff =  rbind(df_diff, df_1[df_1['green']==1,]  -  df_1[df_1['green']==0,] )
}

# %%
# mod_mat <- lm(BVALMidYTM ~ Amt_Issued + mty_years_frm + years_to_maturity + YAS_Yield_Spread +  X260D_volatility +  Cpn + comp_return + 
#               roe + roe_bit  + roc +  number_of_former_directors + number_of_executors + 
#               ecological_index + women_on_board + independent_directors + independence_num  + 
#               + solvency + country_risk_num + rep_risk_num + crs_rating + crif_rating + crif_peer_rating + 
#               + ecological_risk + stability, data = df_diff )

# summary(mod_mat)

# %%
mod_mat <- lm(BVALMidYTM ~ ecological_index + women_on_board + independent_directors + independence_num  + 
              + solvency + country_risk_num + rep_risk_num + crs_rating + crif_rating + crif_peer_rating + 
              + ecological_risk + stability, data = df_diff )


summary(mod_mat)
# Out:
# Call:
# lm(formula = BVALMidYTM ~ ecological_index + women_on_board +
#     independent_directors + independence_num + +solvency + country_risk_num +
#     rep_risk_num + crs_rating + crif_rating + crif_peer_rating +
#     +ecological_risk + stability, data = df_diff)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.1231 -0.8746  0.1647  1.2197  5.5345
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            0.5201381  0.6983609   0.745  0.45807
# ecological_index      -0.1472806  0.0853726  -1.725  0.08747 .
# women_on_board         0.0323200  0.0516995   0.625  0.53324
# independent_directors -0.0002997  0.0281379  -0.011  0.99152
# independence_num       0.1175719  0.1487767   0.790  0.43118
# solvency               0.0024341  0.0140194   0.174  0.86250
# country_risk_num      -0.4703514  0.2059566  -2.284  0.02442 *
# rep_risk_num          -0.2752966  0.2151941  -1.279  0.20364
# crs_rating             0.2927874  0.1943497   1.506  0.13497
# crif_rating            0.0027088  0.0014437   1.876  0.06342 .
# crif_peer_rating      -0.0050372  0.0014993  -3.360  0.00109 **
# ecological_risk        0.1734801  0.0917428   1.891  0.06142 .
# stability              0.0057958  0.0098337   0.589  0.55688
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.342 on 104 degrees of freedom
# Multiple R-squared:  0.2478,	Adjusted R-squared:  0.161
# F-statistic: 2.855 on 12 and 104 DF,  p-value: 0.001981

# %%
library(lmtest)
library(sandwich)
# Out:
# Loading required package: sandwich

# %%
coeftest(mod_mat,vcov = vcovHC(mod_mat, type = "HC0"))
# Out:
# t test of coefficients:
#
#                          Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)            0.52013813  0.65291637  0.7966 0.4274760
# ecological_index      -0.14728057  0.07587265 -1.9412 0.0549459 .
# women_on_board         0.03232001  0.04792412  0.6744 0.5015537
# independent_directors -0.00029975  0.02420613 -0.0124 0.9901437
# independence_num       0.11757194  0.12126265  0.9696 0.3345132
# solvency               0.00243411  0.01247388  0.1951 0.8456670
# country_risk_num      -0.47035141  0.17345108 -2.7117 0.0078331 **
# rep_risk_num          -0.27529661  0.15331860 -1.7956 0.0754646 .
# crs_rating             0.29278742  0.14269712  2.0518 0.0427005 *
# crif_rating            0.00270881  0.00118812  2.2799 0.0246536 *
# crif_peer_rating      -0.00503722  0.00133699 -3.7676 0.0002736 ***
# ecological_risk        0.17348011  0.08528015  2.0342 0.0444728 *
# stability              0.00579580  0.00564499  1.0267 0.3069364
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
